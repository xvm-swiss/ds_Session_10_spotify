# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
os.listdir('../data/raw')
# Out:
# ['spotify-tracks-dataset.csv']

# %%
df =pd.read_csv('../data/raw/spotify-tracks-dataset.csv')

# %%
df.shape
# Out:
# (114000, 22)

# %%
df.sample(4)
# Out:
#        Unnamed: 0.1  Unnamed: 0                track_id  \
# 87491         87491       87491  4GYgRE5xx0GrBOiUdz6HTq
# 82453         82453       82453  59B5CBl2vFYsZogVmCGf0L
# 59965         59965       59965  3j78wdlIk5WfnfddP2qySc
# 65840         65840       65840  5joNJn9LUvYcamWwa2iYCL
#
#                            artists        album_name  \
# 87491                        Leoni   Leoni - Ao Vivo
# 82453  Falconshield;FrivolousShara  PICK YOUR POISON
# 59965                    Nima A.M.     The Frequency
# 65840                   OH MY GIRL           NONSTOP
#
#                                               track_name  popularity  \
# 87491  Alice (Não Me Escreva Aquela Carta de Amor) / ...          45
# 82453                                   PICK YOUR POISON          40
# 59965                                       Love in Fall           0
# 65840                                            Nonstop          62
#
#        duration_ms  explicit  danceability  ...  loudness  mode  speechiness  \
# 87491       201613     False         0.567  ...    -8.201     0       0.0397
# 82453       187494     False         0.653  ...   -12.702     0       0.0794
# 59965       353000     False         0.526  ...    -7.513     1       0.0280
# 65840       202760     False         0.753  ...    -2.591     1       0.0517
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 87491      0.805000             0.000     0.881    0.843   80.557
# 82453      0.107000             0.000     0.219    0.308  144.830
# 59965      0.000317             0.826     0.105    0.254  120.019
# 65840      0.171000             0.000     0.367    0.825  123.983
#
#        time_signature  track_genre
# 87491               4        r-n-b
# 82453               4    power-pop
# 59965               4      iranian
# 65840               4        k-pop
#
# [4 rows x 22 columns]

# %%
df.drop(['Unnamed: 0.1','Unnamed: 0', 'track_id' ], axis=1, inplace= True)

# %%
df.sample(2)
# Out:
#                            artists           album_name  \
# 101114  Traditional;Andrea Bocelli  Classical Christmas
# 17833                     DEADLIFE     Bionic Chrysalis
#
#                           track_name  popularity  duration_ms  explicit  \
# 101114  Angels We Have Heard On High           0       233453     False
# 17833                        For You          16       353061     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 101114         0.158   0.379    7    -5.842     1       0.0303        0.8360
# 17833          0.580   0.569   10    -6.291     0       0.0760        0.0171
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 101114          0.000763     0.113    0.178   89.917               1
# 17833           0.067200     0.089    0.358  122.416               4
#
#        track_genre
# 101114       sleep
# 17833         club

# %%
df.isna().sum()
# Out:
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df["artists"].isna().sum()
# Out:
# np.int64(1)

# %%
df[ df["artists"].isna()]
# Out:
#       artists album_name track_name  popularity  duration_ms  explicit  \
# 65900     NaN        NaN        NaN           0            0     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 65900         0.501   0.583    7     -9.46     0       0.0605          0.69
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 65900           0.00396    0.0747    0.734  138.391               4
#
#       track_genre
# 65900       k-pop

# %%
df[  df["album_name"].isna()]
# Out:
#       artists album_name track_name  popularity  duration_ms  explicit  \
# 65900     NaN        NaN        NaN           0            0     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 65900         0.501   0.583    7     -9.46     0       0.0605          0.69
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 65900           0.00396    0.0747    0.734  138.391               4
#
#       track_genre
# 65900       k-pop

# %%
df[  df["track_name"].isna()]
# Out:
#       artists album_name track_name  popularity  duration_ms  explicit  \
# 65900     NaN        NaN        NaN           0            0     False
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 65900         0.501   0.583    7     -9.46     0       0.0605          0.69
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 65900           0.00396    0.0747    0.734  138.391               4
#
#       track_genre
# 65900       k-pop

# %%
df = df.drop(65900).reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.shape
# Out:
# (113999, 19)

# %%
df.duplicated().sum()
# Out:
# np.int64(577)

# %%
#df.drop_duplicates(keep='last', inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(577)

# %%
df[ df.duplicated()]
# Out:
#                         artists  \
# 1925     Buena Onda Reggae Club
# 2046    The Killers;Ryan Pardey
# 2085      The Smashing Pumpkins
# 2094                     Weezer
# 2155      Red Hot Chili Peppers
# ...                         ...
# 111361                Faithless
# 111979                Morcheeba
# 112967              Acil Servis
# 113344              Matt Redman
# 113881    Bryan & Katie Torwalt
#
#                                               album_name  \
# 1925                                             Disco 2
# 2046                          Alternative Christmas 2022
# 2085                          Alternative Christmas 2022
# 2094                          Alternative Christmas 2022
# 2155                                    Stadium Arcadium
# ...                                                  ...
# 111361                                     Faithless 2.0
# 111979                              Parts of the Process
# 112967                                        Küçük Adam
# 113344  Sing Like Never Before: The Essential Collection
# 113881                I've Got Good News (Live) [Deluxe]
#
#                            track_name  popularity  duration_ms  explicit  \
# 1925                 Song for Rollins          16       219346     False
# 2046             Don't Shoot Me Santa           0       245106     False
# 2085                    Christmastime           0       196723     False
# 2094    We Wish You A Merry Christmas           0        84973     False
# 2155                    Snow (Hey Oh)          80       334666     False
# ...                               ...         ...          ...       ...
# 111361                      Tarantula          21       398152     False
# 111979                 Undress Me Now          17       203773     False
# 112967                          Bebek          38       319933     False
# 113344        Our God - New Recording          34       265373     False
# 113881               Good News - Live          23       266632     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1925           0.841   0.577    0    -7.544     1       0.0438      0.238000
# 2046           0.588   0.847    8    -4.164     1       0.0705      0.060100
# 2085           0.165   0.434    0    -8.163     1       0.0288      0.316000
# 2094           0.387   0.786   11    -4.127     1       0.0436      0.019500
# 2155           0.427   0.900   11    -3.674     1       0.0499      0.116000
# ...              ...     ...  ...       ...   ...          ...           ...
# 111361         0.622   0.816    6   -11.095     0       0.0483      0.009590
# 111979         0.576   0.352    7   -10.773     0       0.0268      0.700000
# 112967         0.486   0.485    5   -12.391     0       0.0331      0.004460
# 113344         0.487   0.895   11    -5.061     1       0.0413      0.000183
# 113881         0.473   0.474    6    -9.175     1       0.0558      0.395000
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 1925            0.860000    0.0571    0.843   90.522               4
# 2046            0.000000    0.3070    0.662  120.041               4
# 2085            0.171000    0.2130    0.186   77.983               3
# 2094            0.000000    0.1230    0.462  149.806               3
# 2155            0.000017    0.1190    0.599  104.655               4
# ...                  ...       ...      ...      ...             ...
# 111361          0.578000    0.0991    0.427  136.007               4
# 111979          0.270000    0.1600    0.360   95.484               4
# 112967          0.000017    0.3690    0.353  120.095               4
# 113344          0.000000    0.3590    0.384  105.021               4
# 113881          0.000000    0.1630    0.251  140.746               4
#
#         track_genre
# 1925       afrobeat
# 2046       alt-rock
# 2085       alt-rock
# 2094       alt-rock
# 2155       alt-rock
# ...             ...
# 111361     trip-hop
# 111979     trip-hop
# 112967      turkish
# 113344  world-music
# 113881  world-music
#
# [577 rows x 19 columns]

# %% [markdown]
# # Extract KPIs as :
# - No. of tracks
# - No. of artists
# - No. of albums
# - Avg song duration is minutes
# - No. of genres

# %%
df.sample(1)
# Out:
#                         artists   album_name       track_name  popularity  \
# 95603  Jorge Leo & Atrato River  Desbordante  Amor Tormentoso          29
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 95603       252107     False         0.688    0.78    4   -10.831     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 95603       0.0517         0.273           0.00208    0.0544    0.653
#
#          tempo  time_signature track_genre
# 95603  177.066               4       salsa

# %%
No_of_tracks = df.drop_duplicates(subset=["track_name"], keep='last').value_counts().sum()

No_of_tracks
# Out:
# np.int64(73608)

# %%
No_of_artists = df.drop_duplicates(subset=['artists'], keep='first').value_counts().sum()
No_of_artists
# Out:
# np.int64(31437)

# %%
No_of_albums = df.drop_duplicates(subset=["album_name"], keep='last').value_counts().sum()

No_of_albums
# Out:
# np.int64(46589)

# %%
df["duration_ms"].mean()/1000
# Out:
# np.float64(228.0311533873104)

# %%
Avg_song_duration_is_minutes = round(df["duration_ms"].mean() / 1000/60, 2)

Avg_song_duration_is_minutes
# Out:
# np.float64(3.8)

# %%
No_of_genres = df.drop_duplicates( subset=["track_genre"], keep="last").value_counts().sum()

No_of_genres
# Out:
# np.int64(114)

# %% [markdown]
# # Extract KPIs as :

# %%
print(f'No. of tracks: {No_of_tracks}')
print(f'No. of artists: {No_of_artists}')
print(f'No. of albums: {No_of_albums}')
print(f'Avg song duration is minutes: {Avg_song_duration_is_minutes}')
print(f'No. of genres: {No_of_genres}')
# Out:
# No. of tracks: 73608
# No. of artists: 31437
# No. of albums: 46589
# Avg song duration is minutes: 3.8
# No. of genres: 114

# %%
df.to_csv('../data/cleaned_data/cleaned_spotifiy_dataset.csv')
